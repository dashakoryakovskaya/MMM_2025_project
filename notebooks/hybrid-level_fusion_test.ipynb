# %%
import pandas as pd
import numpy as np
import torch
import torch.nn as nn
from tqdm import tqdm

import warnings
for warn in [UserWarning, FutureWarning]: warnings.filterwarnings("ignore", category = warn)

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
test = pd.read_csv('../data/test.csv')
item_id = test.item_id

# %%
feature_transformer = pd.read_csv("../results/feature-level-Transformer.csv").deal_probability.values
feature_mamba = pd.read_csv("../results/feature-level-Mamba.csv").deal_probability.values
feature_lstm = pd.read_csv("../results/feature-level-LSTM.csv").deal_probability.values

# %%
decision_catboost_transformer = pd.read_csv("../results/decision_catboost_transformer.csv").deal_probability.values
decision_catboost_lstm = pd.read_csv("../results/decision_catboost_lstm.csv").deal_probability.values
decision_rnn_transformer = pd.read_csv("../results/decision_rnn_transformer.csv").deal_probability.values
decision_rnn_lstm = pd.read_csv("../results/decision_rnn_lstm.csv").deal_probability.values

# %% [markdown]
# ### Tabular + Text

# %% [markdown]
# feature_transformer

# %%
pd.DataFrame({'item_id': item_id, 'deal_probability': (feature_transformer + decision_catboost_transformer) / 2.0}).to_csv("../results/hybrid_transformer_catboost_transformer.csv", index=0)

# %% [markdown]
# Результат: 0.24671

# %%
pd.DataFrame({'item_id': item_id, 'deal_probability': (feature_transformer + decision_catboost_lstm) / 2.0}).to_csv("../results/hybrid_transformer_catboost_lstm.csv", index=0)

# %% [markdown]
# Результат: 0.26203

# %%
pd.DataFrame({'item_id': item_id, 'deal_probability': (feature_transformer + decision_rnn_transformer) / 2.0}).to_csv("../results/hybrid_transformer_rnn_transformer.csv", index=0)

# %% [markdown]
# Результат: 0.26640

# %%
pd.DataFrame({'item_id': item_id, 'deal_probability': (feature_transformer + decision_rnn_lstm) / 2.0}).to_csv("../results/hybrid_transformer_rnn_lstm.csv", index=0)

# %% [markdown]
# Результат: 0.28659

# %% [markdown]
# feature_mamba

# %%
pd.DataFrame({'item_id': item_id, 'deal_probability': (feature_mamba + decision_catboost_transformer) / 2.0}).to_csv("../results/hybrid_mamba_catboost_transformer.csv", index=0)

# %% [markdown]
# Результат: 0.33429

# %%
pd.DataFrame({'item_id': item_id, 'deal_probability': (feature_mamba + decision_catboost_lstm) / 2.0}).to_csv("../results/hybrid_mamba_catboost_lstm.csv", index=0)

# %% [markdown]
# Результат: 0.33412

# %%
pd.DataFrame({'item_id': item_id, 'deal_probability': (feature_mamba + decision_rnn_transformer) / 2.0}).to_csv("../results/hybrid_mamba_rnn_transformer.csv", index=0)

# %% [markdown]
# Результат: 0.31043

# %%
pd.DataFrame({'item_id': item_id, 'deal_probability': (feature_mamba + decision_rnn_lstm) / 2.0}).to_csv("../results/hybrid_mamba_rnn_lstm.csv", index=0)

# %% [markdown]
# Результат: 0.31562

# %% [markdown]
# feature_lstm

# %%
pd.DataFrame({'item_id': item_id, 'deal_probability': (feature_lstm + decision_catboost_transformer) / 2.0}).to_csv("../results/hybrid_lstm_catboost_transformer.csv", index=0)

# %% [markdown]
# Результат: 0.26219

# %%
pd.DataFrame({'item_id': item_id, 'deal_probability': (feature_lstm + decision_catboost_lstm) / 2.0}).to_csv("../results/hybrid_lstm_catboost_lstm.csv", index=0)

# %% [markdown]
# Результат: 0.26934

# %%
pd.DataFrame({'item_id': item_id, 'deal_probability': (feature_lstm + decision_rnn_transformer) / 2.0}).to_csv("../results/hybrid_lstm_rnn_transformer.csv", index=0)

# %% [markdown]
# Результат: 0.25185

# %%
pd.DataFrame({'item_id': item_id, 'deal_probability': (feature_lstm + decision_rnn_lstm) / 2.0}).to_csv("../results/hybrid_lstm_rnn_lstm.csv", index=0)

# %% [markdown]
# Результат: 0.26570

# %% [markdown]
# ### Tabular + Text + Image

# %%
feature_transformer_image = pd.read_csv("../results/feature-level-image-Transformer.csv").deal_probability.values
feature_lstm_image = pd.read_csv("../results/feature-level-image-LSTM.csv").deal_probability.values

# %%
decision_rnn_transformer_transformer = pd.read_csv("../results/decision_rnn_transformer_transformer.csv").deal_probability
decision_rnn_transformer_lstm = pd.read_csv("../results/decision_rnn_transformer_lstm.csv").deal_probability

# %%
pd.DataFrame({'item_id': item_id, 'deal_probability': (feature_transformer_image + decision_rnn_transformer_transformer) / 2.0}).to_csv("../results/hybrid_feature_transformer_rnn_transformer_transformer.csv", index=0)

# %% [markdown]
# Результат: 0.27242

# %%
pd.DataFrame({'item_id': item_id, 'deal_probability': (feature_transformer_image + decision_rnn_transformer_lstm) / 2.0}).to_csv("../results/hybrid_feature_transformer_rnn_transformer_lstm.csv", index=0)

# %% [markdown]
# Результат: 0.27247

# %%
pd.DataFrame({'item_id': item_id, 'deal_probability': (feature_lstm_image + decision_rnn_transformer_transformer) / 2.0}).to_csv("../results/hybrid_feature_lstm_rnn_transformer_transformer.csv", index=0)

# %% [markdown]
# Результат: 0.27113

# %%
pd.DataFrame({'item_id': item_id, 'deal_probability': (feature_lstm_image + decision_rnn_transformer_lstm) / 2.0}).to_csv("../results/hybrid_feature_lstm_rnn_transformer_lstm.csv", index=0)

# %% [markdown]
# Результат: 0.27137
